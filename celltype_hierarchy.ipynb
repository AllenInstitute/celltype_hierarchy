# %%
from analysis_tree_helpers import parse_dend, plot_htree, do_merges
htree_file    = './tree_20180520.csv'
list_changes, descendants, treeobj, leaves, child, parent  = parse_dend(htree_file=htree_file)

# %%
plot_htree(htree_file=htree_file)
#plt.savefig("celltype_hierarchy.pdf", bbox_inches='tight',dpi=600)
